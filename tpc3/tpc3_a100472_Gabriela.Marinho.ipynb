# %% [markdown]
# # TPC 3
# ### Semana de 3 a 7 de Outubro de 2022
# ### A100472 _ Gabriela Marinho

# %% [markdown]
# ### TPC3: Aplicação para manipulação de listas de inteiros
# - Crie uma aplicação em Python que coloca no monitor o seguinte menu:
#     * (1) Criar Lista
#     * (2) Ler Lista
#     * (3) Soma
#     * (4) Média
#     * (5) Maior
#     * (6) Menor
#     * (7) estaOrdenada por ordem crescente
#     * (8) estaOrdenada por ordem decrescente
#     * (9) Procura um elemento
#     * (0) Sair
# - O utilizador irá escolher uma das opções introduzindo o número correspondente;
# - Se a opção não for sair, a aplicação executa a operação pretendida, apresenta o resultado e a seguir apresenta de novo o menu;
# - Se a opção for sair, a aplicação termina colocando uma mensagem no monitor.
#
# * No desenvolvimento da aplicação deverá ter em atenção o seguinte:
#     - A aplicação terá uma variável interna para guardar uma lista de números;
#     - Na opção 1, deverá ser criada uma lista de números aleatórios entre 1 e 100 que será guardada na variável interna;
#     - Na opção 2, deverá ser criada uma lista com números introduzidos pelo utilizador, que será guardada na variável interna;
#     - Nestas primeiras opções, se a variável interna já tiver uma lista, esta será sobreposta/apagada pela nova lista;
#     - Na opção 3, será calculada a soma dos elementos na lista no momento;
#     - Na opção 4, será calculada a média dos elementos na lista no momento;
#     - Na opção 5, será calculado o maior elemento da lista no momento;
#     - Na opção 6, será calculado o menor elemento da lista no momento;
#     - Na opção 7, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem crescente;
#     - Na opção 8, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem decrescente;
#     - Na opção 9, a aplicação irá procurar um ellmento na lista, se o encontrar deverá devolver a sua posição;
#     - Se o utilizador selecionar a opção 0, a aplicação deverá terminar mostrando a lista que está nesse momento guardada.

# %%
print("\033[1m" "_____MENU_____" "\033[0m\n(1) Criar Lista\n(2) Ler Lista\n(3) Soma\n(4) Média\n(5) Maior\n(6) Menor\n(7) estaOrdenada por ordem crescente\n(8) estaOrdenada por ordem decrescente\n(9) Procura um elemento\n(0) Sair")
tecla= int(input("Digite o número correspondente à operação que deseja o efetuar."))

#definir variavel interna:

lista= []
interna = lista
from operator import index

#criar lista aleatória
if tecla==1:
        def aleatoria(elementos):
            elementos = int(input("Vamos criar uma lista aleatória de número entre 0 e 100! Quantos elementos quer na lista?"))
            interna.clear()
            import random
            for i in range(0,elementos):
                n = random.randint(1,101)
                interna.append(n)
            return interna
        print("")
        print(aleatoria(elementos))
        print(" \n \n  ")
        print("\033[1m" "_____MENU_____" "\033[0m\n(1) Criar Lista\n(2) Ler Lista\n(3) Soma\n(4) Média\n(5) Maior\n(6) Menor\n(7) estaOrdenada por ordem crescente\n(8) estaOrdenada por ordem decrescente\n(9) Procura um elemento\n(0) Sair")
        tecla= int(input("Digite o número correspondente à operação que deseja o efetuar."))

#lista criada pelo utilizador
if tecla == 2:
        def criaLista(H):
            interna.clear()
            H= int(input("Aqui pode criar a sua própria lista! Quantos números vai colocar na sua lista?"))
            i= 0
            while (i < H):
                a= int(input("Coloque os números que deseja (pressione enter no fim de cada número)"))
                interna.append(a)
                i = i + 1
            return interna
        print("\nA lista criada é:", criaLista(interna))
        print(" \n \n  ")
        print("\033[1m" "_____MENU_____" "\033[0m\n(1) Criar Lista\n(2) Ler Lista\n(3) Soma\n(4) Média\n(5) Maior\n(6) Menor\n(7) estaOrdenada por ordem crescente\n(8) estaOrdenada por ordem decrescente\n(9) Procura um elemento\n(0) Sair")
        tecla= int(input("Digite o número correspondente à operação que deseja o efetuar."))

#soma dos elementos 
if tecla == 3:
        def listasoma(interna):
            soma = 0
            for i in lista:
                soma = soma + i
            return soma
        print(" ")
        print("A soma dos elementos da sua lista é:", listasoma(interna))
        print(" \n \n  ")
        print("\033[1m" "_____MENU_____" "\033[0m\n(1) Criar Lista\n(2) Ler Lista\n(3) Soma\n(4) Média\n(5) Maior\n(6) Menor\n(7) estaOrdenada por ordem crescente\n(8) estaOrdenada por ordem decrescente\n(9) Procura um elemento\n(0) Sair")
        tecla= int(input("Digite o número correspondente à operação que deseja o efetuar."))
   
#media dos elementos
if tecla == 4:
        def mediaLista(interna):
            sum = 0
            for i in interna:
                sum = sum + i
                media = sum / len(interna)
            return media
        print(" ")
        print("A média dos elementos da sua lista é dada por:", mediaLista(interna))
        print("\n\n")
        print("\033[1m" "_____MENU_____" "\033[0m\n(1) Criar Lista\n(2) Ler Lista\n(3) Soma\n(4) Média\n(5) Maior\n(6) Menor\n(7) estaOrdenada por ordem crescente\n(8) estaOrdenada por ordem decrescente\n(9) Procura um elemento\n(0) Sair")
        tecla= int(input("Digite o número correspondente à operação que deseja o efetuar."))

#maior elemento    
if tecla == 5:
        def maiorLista(interna):
            maior= -
            for i in interna:
                if i > maior:
                    maior = i
            return maior
        print("   ")
        print("O maior elemento é o:", maiorLista(interna))
        print("\n \n")
        print("\033[1m" "_____MENU_____" "\033[0m\n(1) Criar Lista\n(2) Ler Lista\n(3) Soma\n(4) Média\n(5) Maior\n(6) Menor\n(7) estaOrdenada por ordem crescente\n(8) estaOrdenada por ordem decrescente\n(9) Procura um elemento\n(0) Sair")
        tecla= int(input("Digite o número correspondente à operação que deseja o efetuar."))

#menor elemento    
if tecla == 6:
        def menorLista(interna):
            menor= 
            for i in interna:
                if i < menor:
                    menor= i
            return menor
        print("   ")
        print("O menor elemento é o :", menorLista(interna))
        print("\n \n")
        print("\033[1m" "_____MENU_____" "\033[0m\n(1) Criar Lista\n(2) Ler Lista\n(3) Soma\n(4) Média\n(5) Maior\n(6) Menor\n(7) estaOrdenada por ordem crescente\n(8) estaOrdenada por ordem decrescente\n(9) Procura um elemento\n(0) Sair")
        tecla= int(input("Digite o número correspondente à operação que deseja o efetuar."))
        
# verificar se está por ordem crescente
if tecla == 7:
        def estaOrdenada(interna):
            menor= interna[0]
            condicao = True 
            for i in interna:
                if i < menor:
                    condicao = False
                menor= i  
            if condicao==True:
                print("")
                print("SIM!")
            else:
                print(" ")
                print("NÃO!")
        print(estaOrdenada(interna))
        print("\n \n")
        print("\033[1m" "_____MENU_____" "\033[0m\n(1) Criar Lista\n(2) Ler Lista\n(3) Soma\n(4) Média\n(5) Maior\n(6) Menor\n(7) estaOrdenada por ordem crescente\n(8) estaOrdenada por ordem decrescente\n(9) Procura um elemento\n(0) Sair")
        tecla= int(input("Digite o número correspondente à operação que deseja o efetuar."))
        
#verificar se está ordenado de forma decrescente    
if tecla == 8:
        def decrescente(interna):
            maior = interna[0]
            condicao = True
            for i in interna:
                if i > maior:
                    condicao = False
                maior = i
            if condicao == True:
                print("\nSIM!")
            else:
                print("\nNÃO!")
        print(decrescente(interna))
        print("\n \n")
        print("\033[1m" "_____MENU_____" "\033[0m\n(1) Criar Lista\n(2) Ler Lista\n(3) Soma\n(4) Média\n(5) Maior\n(6) Menor\n(7) estaOrdenada por ordem crescente\n(8) estaOrdenada por ordem decrescente\n(9) Procura um elemento\n(0) Sair")
        tecla= int(input("Digite o número correspondente à operação que deseja o efetuar."))

#descobrir a posição de um elemento    
if tecla == 9:
        def procura(interna):
            n= int(input("escreva o elemento que pretende procurar"))
            if n in interna:
                print("\nEsse elemento encontra-se na posição:", interna.index(n))
            else:
                print("\nEsse elemento não faz parte da lista!")
        print("")
        print(procura(interna))
        print("\n \n")
        print("\033[1m" "_____MENU_____" "\033[0m\n(1) Criar Lista\n(2) Ler Lista\n(3) Soma\n(4) Média\n(5) Maior\n(6) Menor\n(7) estaOrdenada por ordem crescente\n(8) estaOrdenada por ordem decrescente\n(9) Procura um elemento\n(0) Sair")
        tecla= int(input("Digite o número correspondente à operação que deseja o efetuar."))

#para terminar o programa   
if tecla == 0:
        print("\nEsta é a última lista guardada pelo programa:",interna)
        
#no caso de não ser selecionado nenhum dos algarismos pedido
else:
        print("\nInsira apenas um dos algarismos disponíveis no MENU")
